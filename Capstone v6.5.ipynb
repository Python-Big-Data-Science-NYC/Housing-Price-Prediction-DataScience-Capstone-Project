# %%
import pandas as pd
#https://docs.google.com/spreadsheets/d/1FPaF_fgOJIEdoJEWS2JS2rlnuyaa1Bl2LZdKUl9egwo/edit?usp=sharing

# %%
Zip_Zhvi_AllHomes = pd.read_csv('http://files.zillowstatic.com/research/public/Zip/Zip_Zhvi_AllHomes.csv')
#Zip_Zhvi_AllHomes.iloc[1,:]
# Out:
# RegionID        84654
# RegionName      60657
# City          Chicago
# State              IL
# Metro         Chicago
# CountyName       Cook
# SizeRank            2
# 1996-04        146700
# 1996-05        146500
# 1996-06        146300
# 1996-07        146300
# 1996-08        146800
# 1996-09        147100
# 1996-10        147300
# 1996-11        147800
# 1996-12        148600
# 1997-01        149100
# 1997-02        149600
# 1997-03        151100
# 1997-04        153200
# 1997-05        155100
# 1997-06        157200
# 1997-07        159100
# 1997-08        160000
# 1997-09        160800
# 1997-10        162200
# 1997-11        163200
# 1997-12        164100
# 1998-01        165600
# 1998-02        167400
#                ...
# 2015-08        308300
# 2015-09        308500
# 2015-10        310100
# 2015-11        311100
# 2015-12        310500
# 2016-01        310900
# 2016-02        312200
# 2016-03        314000
# 2016-04        316100
# 2016-05        316700
# ...

# %%
Zip_Zhvi_AllHomesT= Zip_Zhvi_AllHomes.transpose()
 #.iloc[0,:]
#df.drop()
Zip_Zhvi_AllHomesT.drop(Zip_Zhvi_AllHomesT.index[2:7], inplace= True)
Zip_Zhvi_AllHomesT.drop(Zip_Zhvi_AllHomesT.index[0], inplace= True)
Zip_Zhvi_AllHomesT.columns = Zip_Zhvi_AllHomesT.iloc[0]
Zip_Zhvi_AllHomesT.drop(Zip_Zhvi_AllHomesT.index[0], inplace= True)
Zip_Zhvi_AllHomesT = Zip_Zhvi_AllHomesT.pct_change()

Zip_Zhvi_AllHomesT = Zip_Zhvi_AllHomesT.reset_index()

#>>> pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
Zip_Zhvi_AllHomesT
# Out:
# RegionName    index     10025     60657     60614     79936     60640  \
# 0           1996-04       NaN       NaN       NaN       NaN       NaN
# 1           1996-05       NaN -0.001363 -0.012626  0.002825 -0.009775
# 2           1996-06       NaN -0.001365 -0.006650  0.000000 -0.005923
# 3           1996-07       NaN  0.000000 -0.002060  0.005634 -0.000993
# 4           1996-08       NaN  0.003418  0.000516 -0.002801  0.000994
# 5           1996-09       NaN  0.002044  0.003094  0.005618  0.005958
# 6           1996-10       NaN  0.001360  0.007198  0.013966  0.009872
# 7           1996-11       NaN  0.003394  0.010209  0.006887  0.008798
# 8           1996-12       NaN  0.005413  0.011117 -0.004104  0.011628
# 9           1997-01       NaN  0.003365 -0.001999  0.000000  0.007663
# 10          1997-02       NaN  0.003353 -0.010015  0.001374  0.003802
# 11          1997-03       NaN  0.010027 -0.000506  0.002743  0.007576
# ...

# %%
#Zip_Zhvi_AllHomes.count()

# %%
Zip_Zhvi_AllHomesT = pd.melt(Zip_Zhvi_AllHomesT,  id_vars='index', var_name='zip', value_name='price')
Zip_Zhvi_AllHomesT
# Out:
#            index    zip     price
# 0        1996-04  10025       NaN
# 1        1996-05  10025       NaN
# 2        1996-06  10025       NaN
# 3        1996-07  10025       NaN
# 4        1996-08  10025       NaN
# 5        1996-09  10025       NaN
# 6        1996-10  10025       NaN
# 7        1996-11  10025       NaN
# 8        1996-12  10025       NaN
# 9        1997-01  10025       NaN
# 10       1997-02  10025       NaN
# 11       1997-03  10025       NaN
# 12       1997-04  10025       NaN
# 13       1997-05  10025       NaN
# 14       1997-06  10025       NaN
# 15       1997-07  10025       NaN
# 16       1997-08  10025       NaN
# 17       1997-09  10025       NaN
# 18       1997-10  10025       NaN
# 19       1997-11  10025       NaN
# 20       1997-12  10025       NaN
# 21       1998-01  10025       NaN
# 22       1998-02  10025       NaN
# 23       1998-03  10025       NaN
# 24       1998-04  10025       NaN
# 25       1998-05  10025       NaN
# ...

# %%
from datetime import datetime
datestring = "2008-12"
dt = datetime.strptime(datestring, '%Y-%m')
print (dt.year, dt.month, dt.day)
# Out:
# 2008 12 1

# %%
Zip_Zhvi_AllHomesT['index'] =  pd.to_datetime(Zip_Zhvi_AllHomesT['index'], format='%Y-%m')
Zip_Zhvi_AllHomesT
# Out:
#              index    zip     price
# 0       1996-04-01  10025       NaN
# 1       1996-05-01  10025       NaN
# 2       1996-06-01  10025       NaN
# 3       1996-07-01  10025       NaN
# 4       1996-08-01  10025       NaN
# 5       1996-09-01  10025       NaN
# 6       1996-10-01  10025       NaN
# 7       1996-11-01  10025       NaN
# 8       1996-12-01  10025       NaN
# 9       1997-01-01  10025       NaN
# 10      1997-02-01  10025       NaN
# 11      1997-03-01  10025       NaN
# 12      1997-04-01  10025       NaN
# 13      1997-05-01  10025       NaN
# 14      1997-06-01  10025       NaN
# 15      1997-07-01  10025       NaN
# 16      1997-08-01  10025       NaN
# 17      1997-09-01  10025       NaN
# 18      1997-10-01  10025       NaN
# 19      1997-11-01  10025       NaN
# 20      1997-12-01  10025       NaN
# 21      1998-01-01  10025       NaN
# 22      1998-02-01  10025       NaN
# 23      1998-03-01  10025       NaN
# 24      1998-04-01  10025       NaN
# ...

# %%
Zip_Zhvi_AllHomesT
# Out:
#              index    zip     price
# 0       1996-04-01  10025       NaN
# 1       1996-05-01  10025       NaN
# 2       1996-06-01  10025       NaN
# 3       1996-07-01  10025       NaN
# 4       1996-08-01  10025       NaN
# 5       1996-09-01  10025       NaN
# 6       1996-10-01  10025       NaN
# 7       1996-11-01  10025       NaN
# 8       1996-12-01  10025       NaN
# 9       1997-01-01  10025       NaN
# 10      1997-02-01  10025       NaN
# 11      1997-03-01  10025       NaN
# 12      1997-04-01  10025       NaN
# 13      1997-05-01  10025       NaN
# 14      1997-06-01  10025       NaN
# 15      1997-07-01  10025       NaN
# 16      1997-08-01  10025       NaN
# 17      1997-09-01  10025       NaN
# 18      1997-10-01  10025       NaN
# 19      1997-11-01  10025       NaN
# 20      1997-12-01  10025       NaN
# 21      1998-01-01  10025       NaN
# 22      1998-02-01  10025       NaN
# 23      1998-03-01  10025       NaN
# 24      1998-04-01  10025       NaN
# ...

# %%
AllRegionsForePublic = pd.read_csv('http://files.zillowstatic.com/research/public/AllRegionsForePublic.csv')
# Out:
#          Region         RegionName State  ForecastYoYPctChange  \
# 0      National      United States    US              3.078073
# 1           MSA          Akron, OH    OH              2.515573
# 2           MSA         Albany, GA    GA              3.579034
# 3           MSA         Albany, NY    NY              3.086973
# 4           MSA    Albuquerque, NM    NM              2.859574
# 5           MSA     Alexandria, LA    LA              2.003955
# 6           MSA      Allentown, PA    PA              1.976884
# 7           MSA        Altoona, PA    PA              1.364871
# 8           MSA       Amarillo, TX    TX              2.140482
# 9           MSA           Ames, IA    IA              3.987445
# 10          MSA      Anchorage, AK    AK              5.412158
# 11          MSA      Ann Arbor, MI    MI              4.785821
# 12          MSA       Appleton, WI    WI              3.520030
# 13          MSA      Asheville, NC    NC              2.270682
# ...

# %%
AllRegionsForePublic.head()
# Out:
#      Region       RegionName State  ForecastYoYPctChange          MSAName  \
# 0  National    United States    US              3.078073              NaN
# 1       MSA        Akron, OH    OH              2.515573        Akron, OH
# 2       MSA       Albany, GA    GA              3.579034       Albany, GA
# 3       MSA       Albany, NY    NY              3.086973       Albany, NY
# 4       MSA  Albuquerque, NM    NM              2.859574  Albuquerque, NM
#
#   CountyName CityName
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN

# %%
coest2016alldata = pd.read_csv('https://www2.census.gov/programs-surveys/popest/datasets/2010-2016/counties/totals/co-est2016-alldata.csv',encoding = "ISO-8859-1")

# %%
 #.shape
coest2016alldata = coest2016alldata [coest2016alldata['COUNTY'] !=0]
coest2016alldata
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
states
states = dict (zip(states.values(),states.keys()))

states
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'American Samoa': 'AS',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Guam': 'GU',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'National': 'NA',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Northern Mariana Islands': 'MP',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Puerto Rico': 'PR',
#  'Rhode Island': 'RI',
# ...

# %%
#coest2016alldata = 
coest2016alldata = coest2016alldata.replace({"STNAME": states})
#coest2016alldata

# %%
coest2016alldata['CTYNAME'] = coest2016alldata['CTYNAME'] + ' '+ coest2016alldata['STNAME']

#coest2016alldata.set_index('STNAME', inplace=True)
coest2016alldata['CTYNAME'] = coest2016alldata['CTYNAME'].str.replace('County','')
coest2016alldata.head() #.columns[67:77]
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY STNAME      CTYNAME  CENSUS2010POP  \
# 1      50       3         6      1       1     AL  Autauga  AL          54571
# 2      50       3         6      1       3     AL  Baldwin  AL         182265
# 3      50       3         6      1       5     AL  Barbour  AL          27457
# 4      50       3         6      1       7     AL     Bibb  AL          22915
# 5      50       3         6      1       9     AL   Blount  AL          57322
#
#    ESTIMATESBASE2010  POPESTIMATE2010     ...       RDOMESTICMIG2013  \
# 1              54571            54742     ...              -4.607582
# 2             182265           183199     ...              21.672935
# 3              27457            27348     ...              -7.027927
# 4              22919            22861     ...              -6.556506
# 5              57324            57376     ...              -1.627452
#
#    RDOMESTICMIG2014  RDOMESTICMIG2015  RDOMESTICMIG2016  RNETMIG2011  \
# ...

# %%
listofcols = coest2016alldata.columns #[67:77]
listofcols[77:87]
# Out:
# Index(['GQESTIMATES2014', 'GQESTIMATES2015', 'GQESTIMATES2016', 'RBIRTH2011',
#        'RBIRTH2012', 'RBIRTH2013', 'RBIRTH2014', 'RBIRTH2015', 'RBIRTH2016',
#        'RDEATH2011'],
#       dtype='object')

# %%
coest2016alldata.set_index('CTYNAME', inplace=True)
coest2016alldata
# Out:
#                  SUMLEV  REGION  DIVISION  STATE  COUNTY STNAME  \
# CTYNAME
# Autauga  AL          50       3         6      1       1     AL
# Baldwin  AL          50       3         6      1       3     AL
# Barbour  AL          50       3         6      1       5     AL
# Bibb  AL             50       3         6      1       7     AL
# Blount  AL           50       3         6      1       9     AL
# Bullock  AL          50       3         6      1      11     AL
# Butler  AL           50       3         6      1      13     AL
# Calhoun  AL          50       3         6      1      15     AL
# Chambers  AL         50       3         6      1      17     AL
# Cherokee  AL         50       3         6      1      19     AL
# Chilton  AL          50       3         6      1      21     AL
# Choctaw  AL          50       3         6      1      23     AL
# Clarke  AL           50       3         6      1      25     AL
# ...

# %%
lofc = []
for colname in listofcols:
    lofc.append( colname[:-4])
    #print(colname)

lofc = list(set(lofc))
lofc
# Out:
# ['NATURALINC',
#  'ST',
#  'DEATHS',
#  'CENSUS201',
#  'RINTERNATIONALMIG',
#  'RDEATH',
#  'BIRTHS',
#  'SU',
#  'RNATURALINC',
#  'RDOMESTICMIG',
#  'RESIDUAL',
#  'INTERNATIONALMIG',
#  'CO',
#  'POPESTIMATE',
#  'GQESTIMATESBASE',
#  'GQESTIMATES',
#  'RE',
#  'S',
#  'DOMESTICMIG',
#  'ESTIMATESBASE',
#  'NETMIG',
#  'CTY',
#  'RNETMIG',
#  'NPOPCHG_',
#  'RBIRTH',
#  'DIVI']

# %%
#coest2016alldata = pd.read_csv()

#coest2016alldata.filter(regex='2010').columns

lofc = []
for colname in coest2016alldata.filter(regex='2010').columns:
    lofc.append( colname.replace('2010', ''))
    #print(colname)

lofc = list(set(lofc))
lofc
# Out:
# ['GQESTIMATESBASE',
#  'DOMESTICMIG',
#  'GQESTIMATES',
#  'BIRTHS',
#  'ESTIMATESBASE',
#  'DEATHS',
#  'NATURALINC',
#  'NPOPCHG_',
#  'CENSUSPOP',
#  'RESIDUAL',
#  'INTERNATIONALMIG',
#  'POPESTIMATE',
#  'NETMIG']

# %%
#http://rstudio-pubs-static.s3.amazonaws.com/217450_4fabdb443de345efbc493cf0161ac51d.html

coest2016alldata.filter( like = 'DEATHS' ) #.max()
# Out:
#                  DEATHS2010  DEATHS2011  DEATHS2012  DEATHS2013  DEATHS2014  \
# CTYNAME
# Autauga  AL             154         507         560         582         575
# Baldwin  AL             532        1825        1882        1903        1989
# Barbour  AL             128         318         293         295         313
# Bibb  AL                 34         277         239         281         250
# Blount  AL              132         568         593         584         587
# Bullock  AL              52         132         117         120         115
# Butler  AL               60         261         272         261         288
# Calhoun  AL             313        1326        1357        1411        1392
# Chambers  AL             80         441         475         452         454
# Cherokee  AL            110         310         334         340         347
# Chilton  AL             142         474         495         499         485
# ...

# %%
#coest2016alldata.head()
#coest2016alldata [coest2016alldata.filter( like = 'INTERNATIONALMIG' ) ['INTERNATIONALMIG2016']  ==   42607.000000]

#.max()
# Out:
#                  SUMLEV  REGION  DIVISION  STATE  COUNTY STNAME  \
# CTYNAME
# Los Angeles  CA      50       4         9      6      37     CA
#
#                  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# CTYNAME
# Los Angeles  CA        9818605            9818700          9825473
#
#                  POPESTIMATE2011     ...       RDOMESTICMIG2013  \
# CTYNAME                              ...
# Los Angeles  CA          9888476     ...              -4.337325
#
#                  RDOMESTICMIG2014  RDOMESTICMIG2015  RDOMESTICMIG2016  \
# CTYNAME
# Los Angeles  CA          -5.81594         -6.158125         -7.423938
#
#                  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# CTYNAME
# Los Angeles  CA    -0.801869    -0.508718    -0.727628    -1.699926
#
#                  RNETMIG2015  RNETMIG2016
# CTYNAME
# Los Angeles  CA    -1.853127    -3.215874
#
# [1 rows x 115 columns]

# %%
Zip_Zhvi_AllHomes_county = pd.read_csv('County_MedianListingPricePerSqft_AllHomes.csv')
Zip_Zhvi_AllHomes_county.dropna(thresh=40,inplace= True)

# %%
Zip_Zhvi_AllHomes_county["RegionName"] = Zip_Zhvi_AllHomes_county["RegionName"] + ' '+ Zip_Zhvi_AllHomes_county["State"]
Zip_Zhvi_AllHomes_county.head()
# Out:
#        RegionName State                           Metro  StateCodeFIPS  \
# 0  Los Angeles CA    CA  Los Angeles-Long Beach-Anaheim              6
# 1         Cook IL    IL                         Chicago             17
# 2       Harris TX    TX                         Houston             48
# 3     Maricopa AZ    AZ                         Phoenix              4
# 4    San Diego CA    CA                       San Diego              6
#
#    MunicipalCodeFIPS  SizeRank     2010-01     2010-02     2010-03  \
# 0                 37         1         NaN         NaN         NaN
# 1                 31         2  174.785276  176.430518  177.547708
# 2                201         3   75.057737   76.010822   76.198630
# 3                 13         4         NaN         NaN         NaN
# 4                 73         5         NaN         NaN         NaN
#
#       2010-04     ...         2017-05     2017-06     2017-07     2017-08  \
# ...

# %%
Zip_Zhvi_AllHomes_countyT= Zip_Zhvi_AllHomes_county.transpose()

Zip_Zhvi_AllHomes_countyT.drop(Zip_Zhvi_AllHomes_countyT.index[1:6], inplace= True)
Zip_Zhvi_AllHomes_countyT.columns = Zip_Zhvi_AllHomes_countyT.iloc[0]
Zip_Zhvi_AllHomes_countyT.drop(Zip_Zhvi_AllHomes_countyT.index[0], inplace= True)


#Zip_Zhvi_AllHomes_countyT = Zip_Zhvi_AllHomes_countyT.reset_index()
Zip_Zhvi_AllHomes_countyT.index =  pd.to_datetime(Zip_Zhvi_AllHomes_countyT.index, format='%Y-%m')
Zip_Zhvi_AllHomes_countyT['month'] = pd.DatetimeIndex(Zip_Zhvi_AllHomes_countyT.index).month

Zip_Zhvi_AllHomes_countyT = Zip_Zhvi_AllHomes_countyT.loc[Zip_Zhvi_AllHomes_countyT['month'] == 1]
Zip_Zhvi_AllHomes_countyT = Zip_Zhvi_AllHomes_countyT.pct_change()

del Zip_Zhvi_AllHomes_countyT['month']
# #>>> pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
Zip_Zhvi_AllHomes_countyT
# Out:
# RegionName  Los Angeles CA   Cook IL  Harris TX  Maricopa AZ  San Diego CA  \
# 2010-01-01             NaN       NaN        NaN          NaN           NaN
# 2011-01-01             NaN -0.198175  -0.019901          NaN           NaN
# 2012-01-01             NaN -0.121709  -0.032121          NaN           NaN
# 2013-01-01             NaN -0.008284   0.070297          NaN           NaN
# 2014-01-01             NaN  0.050950   0.126779          NaN           NaN
# 2015-01-01        0.050866  0.056545   0.188205     0.045540      0.046261
# 2016-01-01        0.125296  0.103263   0.091277     0.088822      0.099379
# 2017-01-01        0.071194  0.053197  -0.004711     0.051931      0.049536
# 2018-01-01        0.061963  0.081679   0.047325     0.063000      0.080634
#
# RegionName  Orange CA  Kings NY  Miami-Dade FL  Dallas TX  Queens NY  \
# 2010-01-01        NaN       NaN            NaN        NaN        NaN
# 2011-01-01        NaN       NaN            NaN  -0.097389        NaN
# ...

# %%
Zip_Zhvi_AllHomes_countyT = Zip_Zhvi_AllHomes_countyT.reset_index()

Zip_Zhvi_AllHomes_countyT = pd.melt(Zip_Zhvi_AllHomes_countyT,  id_vars='index', var_name='county', value_name='price')
Zip_Zhvi_AllHomes_countyT
# Out:
#            index            county     price
# 0     2010-01-01    Los Angeles CA       NaN
# 1     2011-01-01    Los Angeles CA       NaN
# 2     2012-01-01    Los Angeles CA       NaN
# 3     2013-01-01    Los Angeles CA       NaN
# 4     2014-01-01    Los Angeles CA       NaN
# 5     2015-01-01    Los Angeles CA  0.050866
# 6     2016-01-01    Los Angeles CA  0.125296
# 7     2017-01-01    Los Angeles CA  0.071194
# 8     2018-01-01    Los Angeles CA  0.061963
# 9     2010-01-01           Cook IL       NaN
# 10    2011-01-01           Cook IL -0.198175
# 11    2012-01-01           Cook IL -0.121709
# 12    2013-01-01           Cook IL -0.008284
# 13    2014-01-01           Cook IL  0.050950
# 14    2015-01-01           Cook IL  0.056545
# 15    2016-01-01           Cook IL  0.103263
# 16    2017-01-01           Cook IL  0.053197
# 17    2018-01-01           Cook IL  0.081679
# 18    2010-01-01         Harris TX       NaN
# 19    2011-01-01         Harris TX -0.019901
# ...

# %%
#Zip_Zhvi_AllHomes_countyT['index'] =  pd.to_datetime(Zip_Zhvi_AllHomes_countyT['index'], format='%Y-%m')
Zip_Zhvi_AllHomes_countyT
# Out:
#            index            county     price
# 0     2010-01-01    Los Angeles CA       NaN
# 1     2011-01-01    Los Angeles CA       NaN
# 2     2012-01-01    Los Angeles CA       NaN
# 3     2013-01-01    Los Angeles CA       NaN
# 4     2014-01-01    Los Angeles CA       NaN
# 5     2015-01-01    Los Angeles CA  0.050866
# 6     2016-01-01    Los Angeles CA  0.125296
# 7     2017-01-01    Los Angeles CA  0.071194
# 8     2018-01-01    Los Angeles CA  0.061963
# 9     2010-01-01           Cook IL       NaN
# 10    2011-01-01           Cook IL -0.198175
# 11    2012-01-01           Cook IL -0.121709
# 12    2013-01-01           Cook IL -0.008284
# 13    2014-01-01           Cook IL  0.050950
# 14    2015-01-01           Cook IL  0.056545
# 15    2016-01-01           Cook IL  0.103263
# 16    2017-01-01           Cook IL  0.053197
# 17    2018-01-01           Cook IL  0.081679
# 18    2010-01-01         Harris TX       NaN
# 19    2011-01-01         Harris TX -0.019901
# ...
