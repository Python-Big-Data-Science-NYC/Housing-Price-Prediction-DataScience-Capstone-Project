# %%
import pandas as pd

# %%
pd.read_csv('http://files.zillowstatic.com/research/public/Zip/Zip_Zhvi_AllHomes.csv')
# Out:
#        RegionID  RegionName               City State  \
# 0         61639       10025           New York    NY
# 1         84654       60657            Chicago    IL
# 2         84616       60614            Chicago    IL
# 3         93144       79936            El Paso    TX
# 4         84640       60640            Chicago    IL
# 5         61807       10467           New York    NY
# 6         91733       77084            Houston    TX
# 7         97564       94109      San Francisco    CA
# 8         90668       75070           McKinney    TX
# 9         62037       11226           New York    NY
# 10        91940       77449            Cypress    TX
# 11        61630       10016           New York    NY
# 12        71831       32162       The Villages    FL
# 13        62045       11235           New York    NY
# 14        84646       60647            Chicago    IL
# 15        74242       37211          Nashville    TN
# 16        96107       90250          Hawthorne    CA
# ...

# %%
pd.read_csv('http://files.zillowstatic.com/research/public/AllRegionsForePublic.csv')
# Out:
#          Region         RegionName State  ForecastYoYPctChange  \
# 0      National      United States    US              3.078073
# 1           MSA          Akron, OH    OH              2.515573
# 2           MSA         Albany, GA    GA              3.579034
# 3           MSA         Albany, NY    NY              3.086973
# 4           MSA    Albuquerque, NM    NM              2.859574
# 5           MSA     Alexandria, LA    LA              2.003955
# 6           MSA      Allentown, PA    PA              1.976884
# 7           MSA        Altoona, PA    PA              1.364871
# 8           MSA       Amarillo, TX    TX              2.140482
# 9           MSA           Ames, IA    IA              3.987445
# 10          MSA      Anchorage, AK    AK              5.412158
# 11          MSA      Ann Arbor, MI    MI              4.785821
# 12          MSA       Appleton, WI    WI              3.520030
# 13          MSA      Asheville, NC    NC              2.270682
# ...

# %%
pd.read_csv('https://www2.census.gov/programs-surveys/popest/datasets/2010-2016/counties/totals/co-est2016-alldata.csv',encoding = "ISO-8859-1")
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...
