# %%
import pandas as pd
#https://docs.google.com/spreadsheets/d/1FPaF_fgOJIEdoJEWS2JS2rlnuyaa1Bl2LZdKUl9egwo/edit?usp=sharing

# %%
Zip_Zhvi_AllHomes = pd.read_csv('http://files.zillowstatic.com/research/public/Zip/Zip_Zhvi_AllHomes.csv')
#Zip_Zhvi_AllHomes.iloc[1,:]

# %%
Zip_Zhvi_AllHomesT= Zip_Zhvi_AllHomes.transpose()
 #.iloc[0,:]
#df.drop()
Zip_Zhvi_AllHomesT.drop(Zip_Zhvi_AllHomesT.index[2:7], inplace= True)
Zip_Zhvi_AllHomesT.drop(Zip_Zhvi_AllHomesT.index[0], inplace= True)
Zip_Zhvi_AllHomesT.columns = Zip_Zhvi_AllHomesT.iloc[0]
Zip_Zhvi_AllHomesT.drop(Zip_Zhvi_AllHomesT.index[0], inplace= True)
Zip_Zhvi_AllHomesT = Zip_Zhvi_AllHomesT.pct_change()

Zip_Zhvi_AllHomesT = Zip_Zhvi_AllHomesT.reset_index()

#>>> pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
Zip_Zhvi_AllHomesT.head()
# Out:
# RegionName    index  10025     60657  75070     60614     79936     77084  \
# 0           1996-04    NaN       NaN    NaN       NaN       NaN       NaN
# 1           1996-05    NaN -0.001363    NaN -0.012626  0.002825 -0.002646
# 2           1996-06    NaN -0.001365    NaN -0.006650  0.000000 -0.003979
# 3           1996-07    NaN  0.000000    NaN -0.002060  0.005634  0.000000
# 4           1996-08    NaN  0.003418    NaN  0.000516 -0.002801 -0.002663
#
# RegionName  10467     60640     77449    ...     21840  59231     12429  \
# 0             NaN       NaN       NaN    ...       NaN    NaN       NaN
# 1             NaN -0.009775  0.002774    ...       NaN    NaN  0.001326
# 2             NaN -0.005923 -0.002766    ...       NaN    NaN  0.003974
# 3             NaN -0.000993 -0.008322    ...       NaN    NaN  0.006596
# 4             NaN  0.000994 -0.004196    ...       NaN    NaN  0.011796
#
# RegionName     54844  97028     12720  97102      1338      3293     21405
# 0                NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 1          -0.000498    NaN -0.007299    NaN -0.008089  0.013228  0.001972
# 2           0.000498    NaN  0.026471    NaN -0.003058  0.031332  0.005118
# 3           0.000000    NaN  0.008596    NaN -0.002045  0.000000  0.011359
# 4          -0.000498    NaN -0.048295    NaN -0.007172 -0.043038  0.010844
#
# [5 rows x 15363 columns]

# %%
#Zip_Zhvi_AllHomes.count()

# %%
Zip_Zhvi_AllHomesT = pd.melt(Zip_Zhvi_AllHomesT,  id_vars='index', var_name='zip', value_name='price')
Zip_Zhvi_AllHomesT.head()
# Out:
#      index    zip  price
# 0  1996-04  10025    NaN
# 1  1996-05  10025    NaN
# 2  1996-06  10025    NaN
# 3  1996-07  10025    NaN
# 4  1996-08  10025    NaN

# %%
Zip_Zhvi_AllHomesT['index'] =  pd.to_datetime(Zip_Zhvi_AllHomesT['index'], format='%Y-%m')
Zip_Zhvi_AllHomesT.head()
# Out:
#        index    zip  price
# 0 1996-04-01  10025    NaN
# 1 1996-05-01  10025    NaN
# 2 1996-06-01  10025    NaN
# 3 1996-07-01  10025    NaN
# 4 1996-08-01  10025    NaN

# %%
Zip_Zhvi_AllHomesT.head()
# Out:
#        index    zip  price
# 0 1996-04-01  10025    NaN
# 1 1996-05-01  10025    NaN
# 2 1996-06-01  10025    NaN
# 3 1996-07-01  10025    NaN
# 4 1996-08-01  10025    NaN

# %%
AllRegionsForePublic = pd.read_csv('http://files.zillowstatic.com/research/public/AllRegionsForePublic.csv')

# %%
AllRegionsForePublic.head()
# Out:
#      Region       RegionName State  ForecastYoYPctChange          MSAName  \
# 0  National    United States    US              3.460955              NaN
# 1       MSA        Akron, OH    OH              2.701606        Akron, OH
# 2       MSA       Albany, GA    GA              3.409518       Albany, GA
# 3       MSA       Albany, NY    NY              2.976953       Albany, NY
# 4       MSA  Albuquerque, NM    NM              2.612778  Albuquerque, NM
#
#   CountyName CityName
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN

# %%
coest2016alldata = pd.read_csv('https://www2.census.gov/programs-surveys/popest/datasets/2010-2016/counties/totals/co-est2016-alldata.csv',encoding = "ISO-8859-1")

# %%
 #.shape
coest2016alldata = coest2016alldata [coest2016alldata['COUNTY'] !=0]
coest2016alldata.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54742     ...
# 2         182265             182265           183199     ...
# 3          27457              27457            27348     ...
# 4          22915              22919            22861     ...
# 5          57322              57324            57376     ...
#
#    RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  RDOMESTICMIG2016  \
# 1         -4.607582          2.149969         -2.799695          4.128528
# 2         21.672935         19.038117         17.311339         19.628723
# 3         -7.027927         -4.208488        -16.593442         -9.495549
# 4         -6.556506          0.088865          0.088747          1.504292
# 5         -1.627452         -2.791093         -1.405067         -1.126712
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  \
# 1     6.163804    -5.295515    -4.571158     2.259290    -2.654256
# 2    15.757654    18.612620    22.757100    20.248574    18.585398
# 3    -1.280316    -7.418561    -7.360829    -4.506434   -16.819716
# 4    -4.956466    -4.318988    -5.980596     0.888652     0.887469
# 5     1.755255    -0.848639    -1.125366    -2.236341    -0.780593
#
#    RNETMIG2016
# 1     4.255281
# 2    20.807611
# 3    -9.686991
# 4     2.300681
# 5    -0.468019
#
# [5 rows x 116 columns]

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
states
states = dict (zip(states.values(),states.keys()))

states
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'American Samoa': 'AS',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Guam': 'GU',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'National': 'NA',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Northern Mariana Islands': 'MP',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Puerto Rico': 'PR',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
#  'Virgin Islands': 'VI',
#  'Virginia': 'VA',
#  'Washington': 'WA',
#  'West Virginia': 'WV',
#  'Wisconsin': 'WI',
#  'Wyoming': 'WY'}

# %%
#coest2016alldata = 
coest2016alldata = coest2016alldata.replace({"STNAME": states})
#coest2016alldata

# %%
coest2016alldata['CTYNAME'] = coest2016alldata['CTYNAME'] + ''+ coest2016alldata['STNAME']

#coest2016alldata.set_index('STNAME', inplace=True)
coest2016alldata['CTYNAME'] = coest2016alldata['CTYNAME'].str.replace('County','')
coest2016alldata.head() #.columns[67:77]
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY STNAME     CTYNAME  CENSUS2010POP  \
# 1      50       3         6      1       1     AL  Autauga AL          54571
# 2      50       3         6      1       3     AL  Baldwin AL         182265
# 3      50       3         6      1       5     AL  Barbour AL          27457
# 4      50       3         6      1       7     AL     Bibb AL          22915
# 5      50       3         6      1       9     AL   Blount AL          57322
#
#    ESTIMATESBASE2010  POPESTIMATE2010     ...       RDOMESTICMIG2013  \
# 1              54571            54742     ...              -4.607582
# 2             182265           183199     ...              21.672935
# 3              27457            27348     ...              -7.027927
# 4              22919            22861     ...              -6.556506
# 5              57324            57376     ...              -1.627452
#
#    RDOMESTICMIG2014  RDOMESTICMIG2015  RDOMESTICMIG2016  RNETMIG2011  \
# 1          2.149969         -2.799695          4.128528     6.163804
# 2         19.038117         17.311339         19.628723    15.757654
# 3         -4.208488        -16.593442         -9.495549    -1.280316
# 4          0.088865          0.088747          1.504292    -4.956466
# 5         -2.791093         -1.405067         -1.126712     1.755255
#
#    RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  RNETMIG2016
# 1    -5.295515    -4.571158     2.259290    -2.654256     4.255281
# 2    18.612620    22.757100    20.248574    18.585398    20.807611
# 3    -7.418561    -7.360829    -4.506434   -16.819716    -9.686991
# 4    -4.318988    -5.980596     0.888652     0.887469     2.300681
# 5    -0.848639    -1.125366    -2.236341    -0.780593    -0.468019
#
# [5 rows x 116 columns]

# %%
listofcols = coest2016alldata.columns #[67:77]
listofcols[77:87]
# Out:
# Index(['GQESTIMATES2014', 'GQESTIMATES2015', 'GQESTIMATES2016', 'RBIRTH2011',
#        'RBIRTH2012', 'RBIRTH2013', 'RBIRTH2014', 'RBIRTH2015', 'RBIRTH2016',
#        'RDEATH2011'],
#       dtype='object')

# %%
coest2016alldata.set_index('CTYNAME', inplace=True)
coest2016alldata
# Out:
#                 SUMLEV  REGION  DIVISION  STATE  COUNTY STNAME  CENSUS2010POP  \
# CTYNAME
# Autauga AL          50       3         6      1       1     AL          54571
# Baldwin AL          50       3         6      1       3     AL         182265
# Barbour AL          50       3         6      1       5     AL          27457
# Bibb AL             50       3         6      1       7     AL          22915
# Blount AL           50       3         6      1       9     AL          57322
# Bullock AL          50       3         6      1      11     AL          10914
# Butler AL           50       3         6      1      13     AL          20947
# Calhoun AL          50       3         6      1      15     AL         118572
# Chambers AL         50       3         6      1      17     AL          34215
# Cherokee AL         50       3         6      1      19     AL          25989
# Chilton AL          50       3         6      1      21     AL          43643
# Choctaw AL          50       3         6      1      23     AL          13859
# Clarke AL           50       3         6      1      25     AL          25833
# Clay AL             50       3         6      1      27     AL          13932
# Cleburne AL         50       3         6      1      29     AL          14972
# Coffee AL           50       3         6      1      31     AL          49948
# Colbert AL          50       3         6      1      33     AL          54428
# Conecuh AL          50       3         6      1      35     AL          13228
# Coosa AL            50       3         6      1      37     AL          11539
# Covington AL        50       3         6      1      39     AL          37765
# Crenshaw AL         50       3         6      1      41     AL          13906
# Cullman AL          50       3         6      1      43     AL          80406
# Dale AL             50       3         6      1      45     AL          50251
# Dallas AL           50       3         6      1      47     AL          43820
# DeKalb AL           50       3         6      1      49     AL          71109
# Elmore AL           50       3         6      1      51     AL          79303
# Escambia AL         50       3         6      1      53     AL          38319
# Etowah AL           50       3         6      1      55     AL         104430
# Fayette AL          50       3         6      1      57     AL          17241
# Franklin AL         50       3         6      1      59     AL          31704
# ...                ...     ...       ...    ...     ...    ...            ...
# Washburn WI         50       2         3     55     129     WI          15911
# Washington WI       50       2         3     55     131     WI         131887
# Waukesha WI         50       2         3     55     133     WI         389891
# Waupaca WI          50       2         3     55     135     WI          52410
# Waushara WI         50       2         3     55     137     WI          24496
# Winnebago WI        50       2         3     55     139     WI         166994
# Wood WI             50       2         3     55     141     WI          74749
# Albany WY           50       4         8     56       1     WY          36299
# Big Horn WY         50       4         8     56       3     WY          11668
# Campbell WY         50       4         8     56       5     WY          46133
# Carbon WY           50       4         8     56       7     WY          15885
# Converse WY         50       4         8     56       9     WY          13833
# Crook WY            50       4         8     56      11     WY           7083
# Fremont WY          50       4         8     56      13     WY          40123
# Goshen WY           50       4         8     56      15     WY          13249
# Hot Springs WY      50       4         8     56      17     WY           4812
# Johnson WY          50       4         8     56      19     WY           8569
# Laramie WY          50       4         8     56      21     WY          91738
# Lincoln WY          50       4         8     56      23     WY          18106
# Natrona WY          50       4         8     56      25     WY          75450
# Niobrara WY         50       4         8     56      27     WY           2484
# Park WY             50       4         8     56      29     WY          28205
# Platte WY           50       4         8     56      31     WY           8667
# Sheridan WY         50       4         8     56      33     WY          29116
# Sublette WY         50       4         8     56      35     WY          10247
# Sweetwater WY       50       4         8     56      37     WY          43806
# Teton WY            50       4         8     56      39     WY          21294
# Uinta WY            50       4         8     56      41     WY          21118
# Washakie WY         50       4         8     56      43     WY           8533
# Weston WY           50       4         8     56      45     WY           7208
#
#                 ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# Coosa AL           ...              -4.851970        -23.430350
# Covington AL       ...               1.742988         -0.290678
# Crenshaw AL        ...              -3.166151          3.168659
# Cullman AL         ...               4.171788          4.336063
# Dale AL            ...             -15.512399        -12.930948
# Dallas AL          ...             -17.804435         -9.846434
# DeKalb AL          ...              -1.748412         -0.648668
# Elmore AL          ...               0.646155         -1.957202
# Escambia AL        ...              -5.082960          0.528018
# Etowah AL          ...              -2.144179         -2.288075
# Fayette AL         ...              -3.961684          0.356305
# Franklin AL        ...              -8.170116         -0.983425
# ...                ...                    ...               ...
# Washburn WI        ...              -6.725888          4.015808
# Washington WI      ...              -2.214122          1.532256
# Waukesha WI        ...               0.101682          0.765097
# Waupaca WI         ...               7.267358         -0.996455
# Waushara WI        ...              -4.343995         -4.617605
# Winnebago WI       ...               0.768590         -2.210961
# Wood WI            ...              -6.977152         -5.834227
# Albany WY          ...              -2.506667         -4.822342
# Big Horn WY        ...              15.404040         -7.957449
# Campbell WY        ...              -6.125766         -8.551532
# Carbon WY          ...               3.748412         -2.972050
# Converse WY        ...              18.737013        -18.482218
# Crook WY           ...               0.838809          5.281078
# Fremont WY         ...              -5.308011        -13.930714
# Goshen WY          ...              -8.087343         -2.214594
# Hot Springs WY     ...               2.065476         -4.358203
# Johnson WY         ...              -0.812678         -9.196205
# Laramie WY         ...               4.928846         -2.539114
# Lincoln WY         ...              13.345466          6.015119
# Natrona WY         ...              25.085476         -2.116610
# Niobrara WY        ...              28.286853        -22.235458
# Park WY            ...               5.419867         -3.851113
# Platte WY          ...              -0.917484          9.612084
# Sheridan WY        ...               4.380275          3.312643
# Sublette WY        ...             -39.617486        -14.725636
# Sweetwater WY      ...              -5.408401        -12.362119
# Teton WY           ...              18.906083         13.904572
# Uinta WY           ...              -7.856582        -14.184397
# Washakie WY        ...              -1.184904        -17.315500
# Weston WY          ...              12.229407          1.533956
#
#                 RDOMESTICMIG2015  RDOMESTICMIG2016  RNETMIG2011  RNETMIG2012  \
# CTYNAME
# Autauga AL             -2.799695          4.128528     6.163804    -5.295515
# Baldwin AL             17.311339         19.628723    15.757654    18.612620
# Barbour AL            -16.593442         -9.495549    -1.280316    -7.418561
# Bibb AL                 0.088747          1.504292    -4.956466    -4.318988
# Blount AL              -1.405067         -1.126712     1.755255    -0.848639
# Bullock AL            -26.456276         -9.703608   -20.634774    -6.923653
# Butler AL              -7.424089         -6.330376    -4.929881    -7.467540
# Calhoun AL             -3.954621         -4.019209    -6.341976    -4.494688
# Chambers AL             1.440350         -4.566479    -1.585740     4.611544
# Cherokee AL            -3.599768          5.286583     6.186359     1.382223
# Chilton AL             -3.398606          1.435897    -0.709114    -3.018833
# Choctaw AL             -5.507148        -13.285485   -14.426230    -1.472808
# Clarke AL              -6.977495        -13.274156    -6.821149   -16.490128
# Clay AL                 2.815023          3.186720   -10.523260   -13.413421
# Cleburne AL            -2.793296         -3.409091    -3.539114    -4.949171
# Coffee AL               2.101748          0.645231     2.721845    10.918319
# Colbert AL              0.036791          0.589802     0.715721     1.560306
# Sweetwater WY     -5.297573   -12.228954   -13.472670   -19.784375
# Teton WY          20.314950    15.720137     3.179512    -2.637040
# Uinta WY          -8.713663   -14.948540   -11.753418   -10.434699
# Washakie WY       -1.658866   -17.793169     2.163462   -11.950027
# Weston WY         12.791678     1.952308     6.662503     2.765104
#
# [3142 rows x 115 columns]

# %%
# lofc = []
# for colname in listofcols:
#     lofc.append( colname[:-4])
#     #print(colname)

# lofc = list(set(lofc))
# lofc

# %%
#coest2016alldata = pd.read_csv()

#coest2016alldata.filter(regex='2010').columns

lofc = []
for colname in coest2016alldata.filter(regex='2016').columns:
    lofc.append( colname) #.replace('2010', ''))
    #print(colname)

lofc = list(set(lofc))
lofc
# Out:
# ['NATURALINC2016',
#  'RBIRTH2016',
#  'INTERNATIONALMIG2016',
#  'RDOMESTICMIG2016',
#  'RINTERNATIONALMIG2016',
#  'DEATHS2016',
#  'RNATURALINC2016',
#  'DOMESTICMIG2016',
#  'NETMIG2016',
#  'POPESTIMATE2016',
#  'BIRTHS2016',
#  'RNETMIG2016',
#  'RDEATH2016',
#  'RESIDUAL2016',
#  'GQESTIMATES2016',
#  'NPOPCHG_2016']

# %%
#output_names = [name for name if (name[0] =='R')]
# https://stackoverflow.com/questions/10134372/get-a-list-of-names-which-start-with-certain-letters

names = lofc
first_letters = ['R']
output_names = [name for name in names if (name[0] in first_letters)]


try:
    output_names.remove( 'RESIDUAL2016')
except ValueError:
    pass

output_names
# Out:
# ['RBIRTH2016',
#  'RDOMESTICMIG2016',
#  'RINTERNATIONALMIG2016',
#  'RNATURALINC2016',
#  'RNETMIG2016',
#  'RDEATH2016']

# %%
xpop = 'RESIDUAL2016'
    
    
    
def makedf (xpop):
    #print (xpop[:-4])
    df  = coest2016alldata.filter( regex = xpop[:-4] ) #.max()
    df = df.reset_index()
    
    df = pd.melt(df, id_vars='CTYNAME',  var_name=xpop+'Year', value_name=xpop)
    df['Year'] = df[xpop+'Year'].str[-4:]
    df['Year'] = pd.to_datetime(df['Year'], format='%Y-%m')
    del df[xpop+'Year']
    df.columns.values[0] = 'county'
    return df

RNETMIG = makedf('RNETMIG2016')
RNETMIG

dflist = []
for colnames in output_names:
    dflist.append(makedf(colnames))
    
dflist[1]
# Out:
#                county  RDOMESTICMIG2016       Year
# 0          Autauga AL          5.836523 2011-01-01
# 1          Baldwin AL         14.768069 2011-01-01
# 2          Barbour AL         -1.133994 2011-01-01
# 3             Bibb AL         -5.395092 2011-01-01
# 4           Blount AL          1.807391 2011-01-01
# 5          Bullock AL        -22.392893 2011-01-01
# 6           Butler AL         -5.025607 2011-01-01
# 7          Calhoun AL         -6.672199 2011-01-01
# 8         Chambers AL         -2.496072 2011-01-01
# 9         Cherokee AL          6.109510 2011-01-01
# 10         Chilton AL         -1.212357 2011-01-01
# 11         Choctaw AL        -14.353370 2011-01-01
# 12          Clarke AL         -6.938083 2011-01-01
# 13            Clay AL        -10.450686 2011-01-01
# 14        Cleburne AL         -3.539114 2011-01-01
# 15          Coffee AL          0.993374 2011-01-01
# 16         Colbert AL          0.146815 2011-01-01
# 17         Conecuh AL          0.303007 2011-01-01
# 18           Coosa AL        -31.910754 2011-01-01
# 19       Covington AL          6.748652 2011-01-01
# 20        Crenshaw AL          2.017291 2011-01-01
# 21         Cullman AL         -1.516159 2011-01-01
# 22            Dale AL        -10.728610 2011-01-01
# 23          Dallas AL        -15.443483 2011-01-01
# 24          DeKalb AL          0.491118 2011-01-01
# 25          Elmore AL          2.092692 2011-01-01
# 26        Escambia AL         -3.031055 2011-01-01
# 27          Etowah AL         -1.121307 2011-01-01
# 28         Fayette AL         -4.957135 2011-01-01
# 29        Franklin AL         -1.418037 2011-01-01
# ...               ...               ...        ...
# 18822     Washburn WI         10.896039 2016-01-01
# 18823   Washington WI          1.104020 2016-01-01
# 18824     Waukesha WI          3.435107 2016-01-01
# 18825      Waupaca WI         -3.093043 2016-01-01
# 18826     Waushara WI          4.522540 2016-01-01
# 18827    Winnebago WI         -0.771835 2016-01-01
# 18828         Wood WI         -2.431777 2016-01-01
# 18829       Albany WY         -6.654877 2016-01-01
# 18830     Big Horn WY         -0.916819 2016-01-01
# 18831     Campbell WY        -20.787479 2016-01-01
# 18832       Carbon WY          0.128320 2016-01-01
# 18833     Converse WY        -17.536476 2016-01-01
# 18834        Crook WY          1.881973 2016-01-01
# 18835      Fremont WY         -4.690001 2016-01-01
# 18836       Goshen WY        -16.307168 2016-01-01
# 18837  Hot Springs WY         -9.974533 2016-01-01
# 18838      Johnson WY        -13.237275 2016-01-01
# 18839      Laramie WY          4.689764 2016-01-01
# 18840      Lincoln WY         12.359046 2016-01-01
# 18841      Natrona WY        -20.241377 2016-01-01
# 18842     Niobrara WY        -12.457304 2016-01-01
# 18843         Park WY          7.533086 2016-01-01
# 18844       Platte WY        -15.441807 2016-01-01
# 18845     Sheridan WY          3.617117 2016-01-01
# 18846     Sublette WY        -18.527945 2016-01-01
# 18847   Sweetwater WY        -20.009453 2016-01-01
# 18848        Teton WY         -4.712087 2016-01-01
# 18849        Uinta WY         -9.761493 2016-01-01
# 18850     Washakie WY        -11.467198 2016-01-01
# 18851       Weston WY          2.212084 2016-01-01
#
# [18852 rows x 3 columns]

# %%
RDEATH  = coest2016alldata.filter( regex = 'RDEATH' ) #.max()
RDEATH = RDEATH.reset_index()
RDEATH = pd.melt(RDEATH, id_vars='CTYNAME',  var_name='DeathYear', value_name='deaths')
RDEATH['Year'] = RDEATH['DeathYear'].str[6:]
RDEATH['Year'] = pd.to_datetime(RDEATH['Year'], format='%Y-%m')
del RDEATH['DeathYear']
RDEATH
# Out:
#               CTYNAME     deaths       Year
# 0          Autauga AL   9.218433 2011-01-01
# 1          Baldwin AL   9.868812 2011-01-01
# 2          Barbour AL  11.632586 2011-01-01
# 3             Bibb AL  12.149922 2011-01-01
# 4           Blount AL   9.871136 2011-01-01
# 5          Bullock AL  12.214306 2011-01-01
# 6           Butler AL  12.492222 2011-01-01
# 7          Calhoun AL  11.227583 2011-01-01
# 8         Chambers AL  12.950211 2011-01-01
# 9         Cherokee AL  11.911623 2011-01-01
# 10         Chilton AL  10.842588 2011-01-01
# 11         Choctaw AL  11.657559 2011-01-01
# 12          Clarke AL  11.654421 2011-01-01
# 13            Clay AL  15.313158 2011-01-01
# 14        Cleburne AL  11.618978 2011-01-01
# 15          Coffee AL  10.092682 2011-01-01
# 16         Colbert AL  12.314073 2011-01-01
# 17         Conecuh AL  14.317097 2011-01-01
# 18           Coosa AL  14.096078 2011-01-01
# 19       Covington AL  12.890980 2011-01-01
# 20        Crenshaw AL  11.815562 2011-01-01
# 21         Cullman AL  11.309054 2011-01-01
# 22            Dale AL   9.355189 2011-01-01
# 23          Dallas AL  12.501867 2011-01-01
# 24          DeKalb AL  10.987006 2011-01-01
# 25          Elmore AL   8.884545 2011-01-01
# 26        Escambia AL  11.497106 2011-01-01
# 27          Etowah AL  12.995663 2011-01-01
# 28         Fayette AL  14.929725 2011-01-01
# 29        Franklin AL  13.171992 2011-01-01
# ...               ...        ...        ...
# 18822     Washburn WI  12.818869 2016-01-01
# 18823   Washington WI   8.205557 2016-01-01
# 18824     Waukesha WI   8.433000 2016-01-01
# 18825      Waupaca WI  14.131338 2016-01-01
# 18826     Waushara WI  10.455781 2016-01-01
# 18827    Winnebago WI   8.537315 2016-01-01
# 18828         Wood WI  10.232590 2016-01-01
# 18829       Albany WY   4.794655 2016-01-01
# 18830     Big Horn WY  10.085014 2016-01-01
# 18831     Campbell WY   6.786500 2016-01-01
# 18832       Carbon WY   8.854100 2016-01-01
# 18833     Converse WY   7.856341 2016-01-01
# 18834        Crook WY   8.872160 2016-01-01
# 18835      Fremont WY  11.935928 2016-01-01
# 18836       Goshen WY  10.229042 2016-01-01
# 18837  Hot Springs WY  14.643463 2016-01-01
# 18838      Johnson WY   8.902946 2016-01-01
# 18839      Laramie WY   8.703710 2016-01-01
# 18840      Lincoln WY   6.390789 2016-01-01
# 18841      Natrona WY   8.932182 2016-01-01
# 18842     Niobrara WY   8.438819 2016-01-01
# 18843         Park WY   8.902738 2016-01-01
# 18844       Platte WY   9.379468 2016-01-01
# 18845     Sheridan WY  11.083642 2016-01-01
# 18846     Sublette WY   5.904510 2016-01-01
# 18847   Sweetwater WY   6.189651 2016-01-01
# 18848        Teton WY   3.761024 2016-01-01
# 18849        Uinta WY   6.443547 2016-01-01
# 18850     Washakie WY  11.225783 2016-01-01
# 18851       Weston WY  10.645652 2016-01-01
#
# [18852 rows x 3 columns]

# %%
#http://rstudio-pubs-static.s3.amazonaws.com/217450_4fabdb443de345efbc493cf0161ac51d.html

DEATHS = coest2016alldata.filter( like = 'DEATHS' ) #.max()
DEATHS = DEATHS.reset_index()
DEATHS = pd.melt(DEATHS, id_vars='CTYNAME',  var_name='DeathYear', value_name='deaths')
DEATHS['Year'] = DEATHS['DeathYear'].str[6:]
DEATHS = DEATHS [DEATHS['Year'] !='2010']
DEATHS['Year'] = pd.to_datetime(DEATHS['Year'], format='%Y-%m')
del DEATHS['DeathYear']
DEATHS = DEATHS.pivot_table(index=['Year'], columns=['CTYNAME'], values='deaths').fillna(0)
DEATHS = DEATHS.pct_change()
DEATHS = DEATHS.reset_index()
DEATHS = pd.melt(DEATHS, id_vars='Year',  var_name='CTYNAME', value_name='deaths')
DEATHS
# Out:
#             Year          CTYNAME    deaths
# 0     2011-01-01     Abbeville SC       NaN
# 1     2012-01-01     Abbeville SC -0.131034
# 2     2013-01-01     Abbeville SC  0.103175
# 3     2014-01-01     Abbeville SC -0.053957
# 4     2015-01-01     Abbeville SC  0.022814
# 5     2016-01-01     Abbeville SC -0.029740
# 6     2011-01-01  Acadia ParishLA       NaN
# 7     2012-01-01  Acadia ParishLA -0.108382
# 8     2013-01-01  Acadia ParishLA  0.119935
# 9     2014-01-01  Acadia ParishLA -0.130246
# 10    2015-01-01  Acadia ParishLA  0.126456
# 11    2016-01-01  Acadia ParishLA -0.013294
# 12    2011-01-01      Accomack VA       NaN
# 13    2012-01-01      Accomack VA -0.083871
# 14    2013-01-01      Accomack VA -0.025822
# 15    2014-01-01      Accomack VA -0.021687
# 16    2015-01-01      Accomack VA  0.152709
# 17    2016-01-01      Accomack VA  0.002137
# 18    2011-01-01           Ada ID       NaN
# 19    2012-01-01           Ada ID  0.019177
# 20    2013-01-01           Ada ID  0.009408
# 21    2014-01-01           Ada ID  0.032621
# 22    2015-01-01           Ada ID  0.055284
# 23    2016-01-01           Ada ID  0.008909
# 24    2011-01-01         Adair IA       NaN
# 25    2012-01-01         Adair IA -0.103448
# 26    2013-01-01         Adair IA  0.134615
# 27    2014-01-01         Adair IA -0.135593
# 28    2015-01-01         Adair IA  0.166667
# 29    2016-01-01         Adair IA -0.168067
# ...          ...              ...       ...
# 18822 2011-01-01          Yuma AZ       NaN
# 18823 2012-01-01          Yuma AZ  0.073936
# 18824 2013-01-01          Yuma AZ -0.062587
# 18825 2014-01-01          Yuma AZ  0.025223
# 18826 2015-01-01          Yuma AZ  0.051375
# 18827 2016-01-01          Yuma AZ  0.075017
# 18828 2011-01-01          Yuma CO       NaN
# 18829 2012-01-01          Yuma CO -0.042373
# 18830 2013-01-01          Yuma CO -0.185841
# 18831 2014-01-01          Yuma CO -0.130435
# 18832 2015-01-01          Yuma CO  0.150000
# 18833 2016-01-01          Yuma CO  0.032609
# 18834 2011-01-01        Zapata TX       NaN
# 18835 2012-01-01        Zapata TX  0.064103
# 18836 2013-01-01        Zapata TX  0.060241
# 18837 2014-01-01        Zapata TX  0.011364
# 18838 2015-01-01        Zapata TX -0.044944
# 18839 2016-01-01        Zapata TX  0.164706
# 18840 2011-01-01        Zavala TX       NaN
# 18841 2012-01-01        Zavala TX  0.277778
# 18842 2013-01-01        Zavala TX -0.065217
# 18843 2014-01-01        Zavala TX  0.116279
# 18844 2015-01-01        Zavala TX  0.072917
# 18845 2016-01-01        Zavala TX -0.067961
# 18846 2011-01-01       Ziebach SD       NaN
# 18847 2012-01-01       Ziebach SD -0.533333
# 18848 2013-01-01       Ziebach SD  1.285714
# 18849 2014-01-01       Ziebach SD -0.375000
# 18850 2015-01-01       Ziebach SD  0.900000
# 18851 2016-01-01       Ziebach SD  0.315789
#
# [18852 rows x 3 columns]

# %%
#coest2016alldata.head()
#coest2016alldata [coest2016alldata.filter( like = 'INTERNATIONALMIG' ) ['INTERNATIONALMIG2016']  ==   42607.000000]

#.max()

# %%
Zip_Zhvi_AllHomes_county = pd.read_csv('County_MedianListingPricePerSqft_AllHomes.csv')
Zip_Zhvi_AllHomes_county.dropna(thresh=40,inplace= True)

# %%
Zip_Zhvi_AllHomes_county["RegionName"] = Zip_Zhvi_AllHomes_county["RegionName"] + ' '+ Zip_Zhvi_AllHomes_county["State"]
Zip_Zhvi_AllHomes_county.head()
# Out:
#        RegionName State                           Metro  StateCodeFIPS  \
# 0  Los Angeles CA    CA  Los Angeles-Long Beach-Anaheim              6
# 1         Cook IL    IL                         Chicago             17
# 2       Harris TX    TX                         Houston             48
# 3     Maricopa AZ    AZ                         Phoenix              4
# 4    San Diego CA    CA                       San Diego              6
#
#    MunicipalCodeFIPS  SizeRank     2010-01     2010-02     2010-03  \
# 0                 37         1         NaN         NaN         NaN
# 1                 31         2  174.785276  176.430518  177.547708
# 2                201         3   75.057737   76.010822   76.198630
# 3                 13         4         NaN         NaN         NaN
# 4                 73         5         NaN         NaN         NaN
#
#       2010-04     ...         2017-05     2017-06     2017-07     2017-08  \
# 0         NaN     ...      405.932534  402.974504  403.773585  405.644758
# 1  176.653797     ...      179.548241  181.391011  180.735325  177.743590
# 2   76.419214     ...      113.324176  113.091954  112.330199  112.718031
# 3         NaN     ...      150.517404  149.749024  148.996413  149.840836
# 4         NaN     ...      349.880383  348.833347  350.584400  352.425835
#
#       2017-09     2017-10     2017-11     2017-12     2018-01     2018-02
# 0  405.762194  407.894737  409.179047  407.014682  408.113217  415.533981
# 1  176.880917  176.282524  173.878706  170.024269  170.359848  176.878931
# 2  113.858962  114.239366  114.677334  115.560658  116.061141  116.717194
# 3  151.248389  153.272577  154.105839  155.209831  156.574911  157.921212
# 4  353.726974  353.903457  354.166667  356.666667  360.478334  366.177764
#
# [5 rows x 104 columns]

# %%
Zip_Zhvi_AllHomes_countyT= Zip_Zhvi_AllHomes_county.transpose()

Zip_Zhvi_AllHomes_countyT.drop(Zip_Zhvi_AllHomes_countyT.index[1:6], inplace= True)
Zip_Zhvi_AllHomes_countyT.columns = Zip_Zhvi_AllHomes_countyT.iloc[0]
Zip_Zhvi_AllHomes_countyT.drop(Zip_Zhvi_AllHomes_countyT.index[0], inplace= True)


#Zip_Zhvi_AllHomes_countyT = Zip_Zhvi_AllHomes_countyT.reset_index()
Zip_Zhvi_AllHomes_countyT.index =  pd.to_datetime(Zip_Zhvi_AllHomes_countyT.index, format='%Y-%m')
Zip_Zhvi_AllHomes_countyT['month'] = pd.DatetimeIndex(Zip_Zhvi_AllHomes_countyT.index).month

Zip_Zhvi_AllHomes_countyT = Zip_Zhvi_AllHomes_countyT.loc[Zip_Zhvi_AllHomes_countyT['month'] == 1]
Zip_Zhvi_AllHomes_countyT = Zip_Zhvi_AllHomes_countyT.pct_change()

del Zip_Zhvi_AllHomes_countyT['month']
# #>>> pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
Zip_Zhvi_AllHomes_countyT
# Out:
# RegionName  Los Angeles CA   Cook IL  Harris TX  Maricopa AZ  San Diego CA  \
# 2010-01-01             NaN       NaN        NaN          NaN           NaN
# 2011-01-01             NaN -0.198175  -0.019901          NaN           NaN
# 2012-01-01             NaN -0.121709  -0.032121          NaN           NaN
# 2013-01-01             NaN -0.008284   0.070297          NaN           NaN
# 2014-01-01             NaN  0.050950   0.126779          NaN           NaN
# 2015-01-01        0.050866  0.056545   0.188205     0.045540      0.046261
# 2016-01-01        0.125296  0.103263   0.091277     0.088822      0.099379
# 2017-01-01        0.071194  0.053197  -0.004711     0.051931      0.049536
# 2018-01-01        0.061963  0.081679   0.047325     0.063000      0.080634
#
# RegionName  Orange CA  Kings NY  Miami-Dade FL  Dallas TX  Queens NY  \
# 2010-01-01        NaN       NaN            NaN        NaN        NaN
# 2011-01-01        NaN       NaN            NaN  -0.097389        NaN
# 2012-01-01        NaN       NaN            NaN  -0.093842        NaN
# 2013-01-01        NaN       NaN            NaN   0.182095        NaN
# 2014-01-01        NaN  0.047424       0.155126   0.089532   0.077726
# 2015-01-01   0.031704  0.302392       0.114909   0.116906   0.111958
# 2016-01-01   0.062612  0.260484       0.264345   0.128639   0.177678
# 2017-01-01   0.051688  0.087515       0.082048   0.204854   0.082660
# 2018-01-01   0.058822  0.057922       0.040303   0.090987   0.122523
#
# RegionName        ...         Granite MT  Hinsdale CO  Arecibo PR  Bayamon PR  \
# 2010-01-01        ...                NaN          NaN         NaN         NaN
# 2011-01-01        ...                NaN          NaN         NaN         NaN
# 2012-01-01        ...                NaN          NaN         NaN         NaN
# 2013-01-01        ...                NaN          NaN         NaN         NaN
# 2014-01-01        ...                NaN          NaN         NaN   -0.200425
# 2015-01-01        ...          -0.064464          NaN         NaN    0.066313
# 2016-01-01        ...           0.125000     0.015933   -0.045469   -0.078664
# 2017-01-01        ...           0.236667     0.032040    0.000479    0.027305
# 2018-01-01        ...          -0.143547     0.058098   -0.092838   -0.094480
#
# RegionName  Fajardo PR  Carolina PR  Guaynabo PR  Cabo Rojo PR  \
# 2010-01-01         NaN          NaN          NaN           NaN
# 2011-01-01         NaN          NaN          NaN           NaN
# 2012-01-01         NaN          NaN          NaN           NaN
# 2013-01-01         NaN          NaN    -0.032336           NaN
# 2014-01-01         NaN          NaN    -0.036754           NaN
# 2015-01-01         NaN          NaN    -0.192606     -0.118235
# 2016-01-01   -0.247870     0.088261    -0.014925     -0.076569
# 2017-01-01    0.077535    -0.074221    -0.043298     -0.031273
# 2018-01-01   -0.262569    -0.134461    -0.067009     -0.030526
#
# RegionName  Saint Thomas VI  Trujillo Alto PR
# 2010-01-01              NaN               NaN
# 2011-01-01              NaN               NaN
# 2012-01-01              NaN               NaN
# 2013-01-01              NaN               NaN
# 2014-01-01              NaN               NaN
# 2015-01-01         0.158508               NaN
# 2016-01-01         0.031599         -0.020392
# 2017-01-01         0.108883         -0.091399
# 2018-01-01         0.000107          0.028249
#
# [9 rows x 1998 columns]

# %%
Zip_Zhvi_AllHomes_countyT = Zip_Zhvi_AllHomes_countyT.reset_index()

Zip_Zhvi_AllHomes_countyT = pd.melt(Zip_Zhvi_AllHomes_countyT,  id_vars='index', var_name='county', value_name='price')
Zip_Zhvi_AllHomes_countyT
# Out:
#            index            county     price
# 0     2010-01-01    Los Angeles CA       NaN
# 1     2011-01-01    Los Angeles CA       NaN
# 2     2012-01-01    Los Angeles CA       NaN
# 3     2013-01-01    Los Angeles CA       NaN
# 4     2014-01-01    Los Angeles CA       NaN
# 5     2015-01-01    Los Angeles CA  0.050866
# 6     2016-01-01    Los Angeles CA  0.125296
# 7     2017-01-01    Los Angeles CA  0.071194
# 8     2018-01-01    Los Angeles CA  0.061963
# 9     2010-01-01           Cook IL       NaN
# 10    2011-01-01           Cook IL -0.198175
# 11    2012-01-01           Cook IL -0.121709
# 12    2013-01-01           Cook IL -0.008284
# 13    2014-01-01           Cook IL  0.050950
# 14    2015-01-01           Cook IL  0.056545
# 15    2016-01-01           Cook IL  0.103263
# 16    2017-01-01           Cook IL  0.053197
# 17    2018-01-01           Cook IL  0.081679
# 18    2010-01-01         Harris TX       NaN
# 19    2011-01-01         Harris TX -0.019901
# 20    2012-01-01         Harris TX -0.032121
# 21    2013-01-01         Harris TX  0.070297
# 22    2014-01-01         Harris TX  0.126779
# 23    2015-01-01         Harris TX  0.188205
# 24    2016-01-01         Harris TX  0.091277
# 25    2017-01-01         Harris TX -0.004711
# 26    2018-01-01         Harris TX  0.047325
# 27    2010-01-01       Maricopa AZ       NaN
# 28    2011-01-01       Maricopa AZ       NaN
# 29    2012-01-01       Maricopa AZ       NaN
# ...          ...               ...       ...
# 17952 2016-01-01       Guaynabo PR -0.014925
# 17953 2017-01-01       Guaynabo PR -0.043298
# 17954 2018-01-01       Guaynabo PR -0.067009
# 17955 2010-01-01      Cabo Rojo PR       NaN
# 17956 2011-01-01      Cabo Rojo PR       NaN
# 17957 2012-01-01      Cabo Rojo PR       NaN
# 17958 2013-01-01      Cabo Rojo PR       NaN
# 17959 2014-01-01      Cabo Rojo PR       NaN
# 17960 2015-01-01      Cabo Rojo PR -0.118235
# 17961 2016-01-01      Cabo Rojo PR -0.076569
# 17962 2017-01-01      Cabo Rojo PR -0.031273
# 17963 2018-01-01      Cabo Rojo PR -0.030526
# 17964 2010-01-01   Saint Thomas VI       NaN
# 17965 2011-01-01   Saint Thomas VI       NaN
# 17966 2012-01-01   Saint Thomas VI       NaN
# 17967 2013-01-01   Saint Thomas VI       NaN
# 17968 2014-01-01   Saint Thomas VI       NaN
# 17969 2015-01-01   Saint Thomas VI  0.158508
# 17970 2016-01-01   Saint Thomas VI  0.031599
# 17971 2017-01-01   Saint Thomas VI  0.108883
# 17972 2018-01-01   Saint Thomas VI  0.000107
# 17973 2010-01-01  Trujillo Alto PR       NaN
# 17974 2011-01-01  Trujillo Alto PR       NaN
# 17975 2012-01-01  Trujillo Alto PR       NaN
# 17976 2013-01-01  Trujillo Alto PR       NaN
# 17977 2014-01-01  Trujillo Alto PR       NaN
# 17978 2015-01-01  Trujillo Alto PR       NaN
# 17979 2016-01-01  Trujillo Alto PR -0.020392
# 17980 2017-01-01  Trujillo Alto PR -0.091399
# 17981 2018-01-01  Trujillo Alto PR  0.028249
#
# [17982 rows x 3 columns]

# %%
#Zip_Zhvi_AllHomes_countyT['index'] =  pd.to_datetime(Zip_Zhvi_AllHomes_countyT['index'], format='%Y-%m')

#Zip_Zhvi_AllHomes_countyT.rename(columns={'year':'Year'}, inplace=True)
Zip_Zhvi_AllHomes_countyT.columns.values[0] = 'Year'

Zip_Zhvi_AllHomes_countyT
# Out:
#             Year            county     price
# 0     2010-01-01    Los Angeles CA       NaN
# 1     2011-01-01    Los Angeles CA       NaN
# 2     2012-01-01    Los Angeles CA       NaN
# 3     2013-01-01    Los Angeles CA       NaN
# 4     2014-01-01    Los Angeles CA       NaN
# 5     2015-01-01    Los Angeles CA  0.050866
# 6     2016-01-01    Los Angeles CA  0.125296
# 7     2017-01-01    Los Angeles CA  0.071194
# 8     2018-01-01    Los Angeles CA  0.061963
# 9     2010-01-01           Cook IL       NaN
# 10    2011-01-01           Cook IL -0.198175
# 11    2012-01-01           Cook IL -0.121709
# 12    2013-01-01           Cook IL -0.008284
# 13    2014-01-01           Cook IL  0.050950
# 14    2015-01-01           Cook IL  0.056545
# 15    2016-01-01           Cook IL  0.103263
# 16    2017-01-01           Cook IL  0.053197
# 17    2018-01-01           Cook IL  0.081679
# 18    2010-01-01         Harris TX       NaN
# 19    2011-01-01         Harris TX -0.019901
# 20    2012-01-01         Harris TX -0.032121
# 21    2013-01-01         Harris TX  0.070297
# 22    2014-01-01         Harris TX  0.126779
# 23    2015-01-01         Harris TX  0.188205
# 24    2016-01-01         Harris TX  0.091277
# 25    2017-01-01         Harris TX -0.004711
# 26    2018-01-01         Harris TX  0.047325
# 27    2010-01-01       Maricopa AZ       NaN
# 28    2011-01-01       Maricopa AZ       NaN
# 29    2012-01-01       Maricopa AZ       NaN
# ...          ...               ...       ...
# 17952 2016-01-01       Guaynabo PR -0.014925
# 17953 2017-01-01       Guaynabo PR -0.043298
# 17954 2018-01-01       Guaynabo PR -0.067009
# 17955 2010-01-01      Cabo Rojo PR       NaN
# 17956 2011-01-01      Cabo Rojo PR       NaN
# 17957 2012-01-01      Cabo Rojo PR       NaN
# 17958 2013-01-01      Cabo Rojo PR       NaN
# 17959 2014-01-01      Cabo Rojo PR       NaN
# 17960 2015-01-01      Cabo Rojo PR -0.118235
# 17961 2016-01-01      Cabo Rojo PR -0.076569
# 17962 2017-01-01      Cabo Rojo PR -0.031273
# 17963 2018-01-01      Cabo Rojo PR -0.030526
# 17964 2010-01-01   Saint Thomas VI       NaN
# 17965 2011-01-01   Saint Thomas VI       NaN
# 17966 2012-01-01   Saint Thomas VI       NaN
# 17967 2013-01-01   Saint Thomas VI       NaN
# 17968 2014-01-01   Saint Thomas VI       NaN
# 17969 2015-01-01   Saint Thomas VI  0.158508
# 17970 2016-01-01   Saint Thomas VI  0.031599
# 17971 2017-01-01   Saint Thomas VI  0.108883
# 17972 2018-01-01   Saint Thomas VI  0.000107
# 17973 2010-01-01  Trujillo Alto PR       NaN
# 17974 2011-01-01  Trujillo Alto PR       NaN
# 17975 2012-01-01  Trujillo Alto PR       NaN
# 17976 2013-01-01  Trujillo Alto PR       NaN
# 17977 2014-01-01  Trujillo Alto PR       NaN
# 17978 2015-01-01  Trujillo Alto PR       NaN
# 17979 2016-01-01  Trujillo Alto PR -0.020392
# 17980 2017-01-01  Trujillo Alto PR -0.091399
# 17981 2018-01-01  Trujillo Alto PR  0.028249
#
# [17982 rows x 3 columns]

# %%
Zip_Zhvi_AllHomes_countyT[Zip_Zhvi_AllHomes_countyT['county'].str.contains("Queens")]['county'].tolist()
# Out:
# ['Queens NY',
#  'Queens NY',
#  'Queens NY',
#  'Queens NY',
#  'Queens NY',
#  'Queens NY',
#  'Queens NY',
#  'Queens NY',
#  'Queens NY']

# %%
RDEATH #['CTYNAME']

#RNETMIG.rename(columns={'CTYNAME':'county'}, inplace=True)

#RNETMIG[RNETMIG['county'].str.contains("Queens")]['county'].tolist()

# %%
#s1 = 

mergeddf = Zip_Zhvi_AllHomes_countyT

for df in dflist:
    #print (df)
    mergeddf = pd.merge(df, mergeddf, how='inner', left_on=['county', 'Year'],right_on=['county', 'Year'])

mergeddf
# Out:
#                county  RDEATH2016       Year  RNETMIG2016  RNATURALINC2016  \
# 0          Autauga AL    9.218433 2011-01-01     6.163804         2.345519
# 1          Baldwin AL    9.868812 2011-01-01    15.757654         1.962947
# 2          Barbour AL   11.632586 2011-01-01    -1.280316         0.621868
# 3             Bibb AL   12.149922 2011-01-01    -4.956466        -0.482488
# 4           Blount AL    9.871136 2011-01-01     1.755255         3.058662
# 5           Butler AL   12.492222 2011-01-01    -4.929881         0.717944
# 6          Calhoun AL   11.227583 2011-01-01    -6.341976         0.491101
# 7         Chambers AL   12.950211 2011-01-01    -1.585740        -1.174622
# 8         Cherokee AL   11.911623 2011-01-01     6.186359        -3.419789
# 9          Chilton AL   10.842588 2011-01-01    -0.709114         2.081594
# 10          Coffee AL   10.092682 2011-01-01     2.721845         3.397340
# 11         Colbert AL   12.314073 2011-01-01     0.715721        -1.229572
# 12       Covington AL   12.890980 2011-01-01     6.933186        -0.685410
# 13         Cullman AL   11.309054 2011-01-01    -1.193043         1.056340
# 14            Dale AL    9.355189 2011-01-01    -9.574140         4.458643
# 15          Elmore AL    8.884545 2011-01-01     2.518750         3.233022
# 16        Escambia AL   11.497106 2011-01-01    -2.978796         1.149711
# 17          Etowah AL   12.995663 2011-01-01    -0.757122        -0.996718
# 18        Franklin AL   13.171992 2011-01-01     0.189072         0.063024
# 19          Geneva AL   12.379053 2011-01-01     1.305021        -0.447436
# 20           Henry AL   13.199228 2011-01-01     7.954120        -2.363180
# 21         Houston AL    8.928746 2011-01-01     2.760862         4.102132
